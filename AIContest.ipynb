# %% [markdown]
# <a href="https://colab.research.google.com/github/T-y-c-o-o-n/colab/blob/master/AIContest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
from PIL import Image


import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import matplotlib.pyplot as plt


import torchvision.transforms as transforms
import torchvision.models as models

import numpy as np

import pandas as pd

import copy
from google.colab import drive
drive.mount("/content/drive")



df_train = pd.read_csv('drive/My Drive/added_train.csv', index_col='id')
df_test = pd.read_csv('drive/My Drive/added_test.csv', index_col='id')



X = df_train.drop(columns=['skilled', 'player_team', 'winner_team'])
X_test = df_test.drop(columns=['player_team', 'winner_team'])
y = df_train['skilled']
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-225c109996e9> in <module>()
#      24
#      25
# ---> 26 df_train = pd.read_csv('drive/My Drive/added_train.csv', index_col='id')
#      27 df_test = pd.read_csv('drive/My Drive/added_test.csv', index_col='id')
#      28
#
# ...

# %%
df_train.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ae4c411233fc> in <module>()
# ----> 1 df_train.head()
#
# NameError: name 'df_train' is not defined

# %%
# !pip install catboost

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

from catboost import CatBoostClassifier

# %%
model_cb = CatBoostClassifier(
    iterations = 15000,
    max_depth = 8).fit(X, y)
y_pred_cb = model_cb.predict_proba(X_test)[:, 1]

y_pred = (y_pred_cb > 0.5).astype(int)


df_submission = pd.DataFrame({'skilled': y_pred}, index=df_test.index)
#df_submission.to_csv('submission_ensemble_cat_2.csv')
df_submission.to_csv('drive/My Drive/submission_ensemble_14000_8.csv')
# Out:
# Learning rate set to 0.005522
# 0:	learn: 0.6922146	total: 168ms	remaining: 42m 4s
# 1:	learn: 0.6912809	total: 335ms	remaining: 41m 48s
# 2:	learn: 0.6903563	total: 507ms	remaining: 42m 16s
# 3:	learn: 0.6894704	total: 669ms	remaining: 41m 48s
# 4:	learn: 0.6885544	total: 841ms	remaining: 42m 2s
# 5:	learn: 0.6876454	total: 1.01s	remaining: 41m 54s
# 6:	learn: 0.6867347	total: 1.18s	remaining: 42m 4s
# 7:	learn: 0.6858731	total: 1.35s	remaining: 42m 15s
# 8:	learn: 0.6850518	total: 1.52s	remaining: 42m 11s
# 9:	learn: 0.6841985	total: 1.71s	remaining: 42m 36s
# 10:	learn: 0.6833391	total: 1.88s	remaining: 42m 37s
# 11:	learn: 0.6825148	total: 2.04s	remaining: 42m 29s
# 12:	learn: 0.6817007	total: 2.21s	remaining: 42m 24s
# 13:	learn: 0.6808974	total: 2.38s	remaining: 42m 23s
# 14:	learn: 0.6800742	total: 2.55s	remaining: 42m 24s
# 15:	learn: 0.6792493	total: 2.71s	remaining: 42m 17s
# 16:	learn: 0.6784732	total: 2.87s	remaining: 42m 10s
# ...
